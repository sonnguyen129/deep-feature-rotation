# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/style-transfer-research/LinearStyleTransfer
# !ls
# Out:
# /content/gdrive/MyDrive/style-transfer-research/LinearStyleTransfer
# data  LICENSE	      README.md		 TestPhotoReal.py  TrainSPN.py
# doc   LST-test.ipynb  real-time-demo.py  TestVideo.py
# libs  models	      TestArtistic.py	 Train.py

# %%
# %%bash
# # unzip models.zip
# # rm models.zip

# %%
# !pip install torch==0.4.1 opencv-python==3.4.2.17
# !pip install torchfile
# Out:
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5710 sha256=6caf5a45709ad315dccaf0f46543148752d3ff0f90f031a7be2ff5509f4798ec
#   Stored in directory: /root/.cache/pip/wheels/ac/5c/3a/a80e1c65880945c71fd833408cd1e9a8cb7e2f8f37620bb75b
# Successfully built torchfile
# ...

# %%
# !python TestArtistic.py
# Out:
# ----------------- Options ---------------
#                 batchSize: 1
#               contentPath: data/content/
#                      cuda: True
#               decoder_dir: models/dec_r41.pth
#                  fineSize: 256
#                     layer: r41
#                  loadSize: 256
#                matrixPath: models/r41.pth
#                      outf: Artistic/
#                 stylePath: data/style/
#                   vgg_dir: models/vgg_r41.pth
# ----------------- End -------------------
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Transferred image saved at Artistic/123057_Vassily_Kandinsky.png
# ...
