# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/style-transfer-research/AdaAttN
# !ls
# Out:
# /content/gdrive/MyDrive/style-transfer-research/AdaAttN
# AdaAttn-test.ipynb  datasets  picture	 test_adaattn.sh   train.py
# checkpoints	    models    README.md  test.py	   util
# data		    options   results	 train_adaattn.sh

# %%
# !pip install dominate

# %%
# !bash test_adaattn.sh
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#              content_path: datasets/contents             	[default: None]
#                crop_ratio: 1.0
#                 crop_size: 512                           	[default: 256]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#        image_encoder_path: checkpoints/vgg_normalised.pth	[default: None]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                load_ratio: 1.0
#                 load_size: 512                           	[default: 256]
#          max_dataset_size: inf
# ...
