# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/MyDrive/style-transfer-research/SAFIN
# !ls
# Out:
# /content/gdrive/MyDrive/style-transfer-research/SAFIN
# function.py  output	  requirements.txt  sampler.py	utils.py
# input	     __pycache__  results.jpg	    test.py	wave_net.py
# models	     README.md	  safin-test.ipynb  train.py

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 20.3 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 2.1 MB 32.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 54.4 MB/s
# ...
#      |████████████████████████████████| 216 kB 64.7 MB/s
# ...
#      |████████████████████████████████| 748.9 MB 673 bytes/s
# ...
#      |████████████████████████████████| 8.8 MB 25.1 MB/s
# ...
#      |████████████████████████████████| 50 kB 8.6 MB/s
# ...
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: torch
#     Found existing installation: torch 1.9.0+cu111
#     Uninstalling torch-1.9.0+cu111:
#       Successfully uninstalled torch-1.9.0+cu111
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python test.py --net_file wave_net --content input/content/257098.jpg --style input/style/contrast_of_forms.jpg
